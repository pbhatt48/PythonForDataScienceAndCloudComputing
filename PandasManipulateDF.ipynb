# %%
import numpy as np
import pandas as pd
df = pd. read_csv('carprice.csv')
df.head()
# Out:
#    car_id  price  Kilometers   hp  Brand Sport  age  Users    gas Metalilic  \
# 0    3548  48750         NaN  110      6   YES    7      1  590.0        NO
# 1     903  16610         NaN  110      3    NO    8      1  391.0       YES
# 2    3903  27100      3040.0  110      2   YES    8      1  478.0        NO
# 3    5098  24240      4690.0  110      5    NO    8      1    NaN        NO
# 4    3364  13030      5820.0  110      5    NO    9      1    NaN       YES
#
#      CC  Weight  QuartTax Automatic  red Owner_gender  door
# 0  1800  1170.0       100       YES   NO            M     4
# 1  2200  1250.0       270       YES   NO            F     4
# 2  1900  1186.0       120       YES  YES            M     4
# 3  1800  1170.0       100       YES   NO            M     4
# 4  2200  1250.0        80        NO   NO            F     4

# %%
df.loc[df.price>10000, 'Ratio'] = df.price/df.Weight
df
# Out:
#       car_id  price  Kilometers   hp  Brand Sport  age  Users    gas  \
# 0       3548  48750         NaN  110      6   YES    7      1  590.0
# 1        903  16610         NaN  110      3    NO    8      1  391.0
# 2       3903  27100      3040.0  110      2   YES    8      1  478.0
# 3       5098  24240      4690.0  110      5    NO    8      1    NaN
# 4       3364  13030      5820.0  110      5    NO    9      1    NaN
# 5       2854  13940    106710.0  110      6    NO    9      1  357.0
# 6       4187  22190      8610.0  110      4    NO    9      1  360.0
# 7        460  51300     11040.0  192      3    NO    9      1  380.0
# 8       3587  35050     12720.0  192      5   YES   10      2  617.0
# 9       1880  17290     11490.0  110      2    NO    9      2  382.0
# 10      2129  14000     12180.0  110      5    NO    9      1  323.0
# 11      3885  82540     17700.0  192      6    NO   10      1  323.0
# 12      1341  19840     15330.0  110      1   YES    9      1  575.0
# ...

# %%
df.loc[(df.price > 10000) & (df.hp >=90), 'Time'] = '2018-01-01'
df.loc[(df.price > 10000) & (df.hp < 90), 'Time'] = '2010-01-01'
df
# Out:
#       car_id  price  Kilometers   hp  Brand Sport  age  Users    gas  \
# 0       3548  48750         NaN  110      6   YES    7      1  590.0
# 1        903  16610         NaN  110      3    NO    8      1  391.0
# 2       3903  27100      3040.0  110      2   YES    8      1  478.0
# 3       5098  24240      4690.0  110      5    NO    8      1    NaN
# 4       3364  13030      5820.0  110      5    NO    9      1    NaN
# 5       2854  13940    106710.0  110      6    NO    9      1  357.0
# 6       4187  22190      8610.0  110      4    NO    9      1  360.0
# 7        460  51300     11040.0  192      3    NO    9      1  380.0
# 8       3587  35050     12720.0  192      5   YES   10      2  617.0
# 9       1880  17290     11490.0  110      2    NO    9      2  382.0
# 10      2129  14000     12180.0  110      5    NO    9      1  323.0
# 11      3885  82540     17700.0  192      6    NO   10      1  323.0
# 12      1341  19840     15330.0  110      1   YES    9      1  575.0
# ...

# %%
df.head()
# Out:
#    car_id  price  Kilometers   hp  Brand Sport  age  Users    gas Metalilic  \
# 0    3548  48750         NaN  110      6   YES    7      1  590.0        NO
# 1     903  16610         NaN  110      3    NO    8      1  391.0       YES
# 2    3903  27100      3040.0  110      2   YES    8      1  478.0        NO
# 3    5098  24240      4690.0  110      5    NO    8      1    NaN        NO
# 4    3364  13030      5820.0  110      5    NO    9      1    NaN       YES
#
#      CC  Weight  QuartTax Automatic  red Owner_gender  door      Ratio  \
# 0  1800  1170.0       100       YES   NO            M     4  41.666667
# 1  2200  1250.0       270       YES   NO            F     4  13.288000
# 2  1900  1186.0       120       YES  YES            M     4  22.849916
# 3  1800  1170.0       100       YES   NO            M     4  20.717949
# 4  2200  1250.0        80        NO   NO            F     4  10.424000
#
#          Time
# 0  2018-01-01
# 1  2018-01-01
# 2  2018-01-01
# 3  2018-01-01
# ...

# %%
df1 = df[['car_id','price']].head(3)
df1
# Out:
#    car_id  price
# 0    3548  48750
# 1     903  16610
# 2    3903  27100

# %%
df2 = df[['car_id','gas']].head(4)
df2
# Out:
#    car_id    gas
# 0    3548  590.0
# 1     903  391.0
# 2    3903  478.0
# 3    5098    NaN

# %%
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#    car_id    price  car_id    gas
# 0  3548.0  48750.0    3548  590.0
# 1   903.0  16610.0     903  391.0
# 2  3903.0  27100.0    3903  478.0
# 3     NaN      NaN    5098    NaN

# %%
df.head()
# Out:
#    car_id  price  Kilometers   hp  Brand Sport  age  Users    gas Metalilic  \
# 0    3548  48750         NaN  110      6   YES    7      1  590.0        NO
# 1     903  16610         NaN  110      3    NO    8      1  391.0       YES
# 2    3903  27100      3040.0  110      2   YES    8      1  478.0        NO
# 3    5098  24240      4690.0  110      5    NO    8      1    NaN        NO
# 4    3364  13030      5820.0  110      5    NO    9      1    NaN       YES
#
#      CC  Weight  QuartTax Automatic  red Owner_gender  door      Ratio  \
# 0  1800  1170.0       100       YES   NO            M     4  41.666667
# 1  2200  1250.0       270       YES   NO            F     4  13.288000
# 2  1900  1186.0       120       YES  YES            M     4  22.849916
# 3  1800  1170.0       100       YES   NO            M     4  20.717949
# 4  2200  1250.0        80        NO   NO            F     4  10.424000
#
#          Time
# 0  2018-01-01
# 1  2018-01-01
# 2  2018-01-01
# 3  2018-01-01
# ...

# %%
df.gas = df.gas + 1
df
# Out:
#       car_id  price  Kilometers   hp  Brand Sport  age  Users    gas  \
# 0       3548  48750         NaN  110      6   YES    7      1  591.0
# 1        903  16610         NaN  110      3    NO    8      1  392.0
# 2       3903  27100      3040.0  110      2   YES    8      1  479.0
# 3       5098  24240      4690.0  110      5    NO    8      1    NaN
# 4       3364  13030      5820.0  110      5    NO    9      1    NaN
# 5       2854  13940    106710.0  110      6    NO    9      1  358.0
# 6       4187  22190      8610.0  110      4    NO    9      1  361.0
# 7        460  51300     11040.0  192      3    NO    9      1  381.0
# 8       3587  35050     12720.0  192      5   YES   10      2  618.0
# 9       1880  17290     11490.0  110      2    NO    9      2  383.0
# 10      2129  14000     12180.0  110      5    NO    9      1  324.0
# 11      3885  82540     17700.0  192      6    NO   10      1  324.0
# 12      1341  19840     15330.0  110      1   YES    9      1  576.0
# ...

# %%
df.loc[(df.age > 5) &(df.age < 9), 'gas'] = df.gas + 5
df
# Out:
#       car_id  price  Kilometers   hp  Brand Sport  age  Users    gas  \
# 0       3548  48750         NaN  110      6   YES    7      1  596.0
# 1        903  16610         NaN  110      3    NO    8      1  397.0
# 2       3903  27100      3040.0  110      2   YES    8      1  484.0
# 3       5098  24240      4690.0  110      5    NO    8      1    NaN
# 4       3364  13030      5820.0  110      5    NO    9      1    NaN
# 5       2854  13940    106710.0  110      6    NO    9      1  358.0
# 6       4187  22190      8610.0  110      4    NO    9      1  361.0
# 7        460  51300     11040.0  192      3    NO    9      1  381.0
# 8       3587  35050     12720.0  192      5   YES   10      2  618.0
# 9       1880  17290     11490.0  110      2    NO    9      2  383.0
# 10      2129  14000     12180.0  110      5    NO    9      1  324.0
# 11      3885  82540     17700.0  192      6    NO   10      1  324.0
# 12      1341  19840     15330.0  110      1   YES    9      1  576.0
# ...

# %%
consumers = pd.read_csv('consumers_ext.csv')
consumers.head()
# Out:
#   customer_id  income  age  owner education gender  spend
# 0       Cus_1  111000   26      0   College      M  56000
# 1       Cus_2   79000   82      0   College      F  29000
# 2       Cus_3   42000   72      0    Master      F  17000
# 3       Cus_4   83000   54      0    Others      F  24000
# 4       Cus_5   70000   66      0   College      F  26000

# %%
consumers1 = consumers.rename(columns={'gender':'sex'})
consumers1.head()
# Out:
#   customer_id  income  age  owner education sex  spend
# 0       Cus_1  111000   26      0   College   M  56000
# 1       Cus_2   79000   82      0   College   F  29000
# 2       Cus_3   42000   72      0    Master   F  17000
# 3       Cus_4   83000   54      0    Others   F  24000
# 4       Cus_5   70000   66      0   College   F  26000

# %%
consumers.head()
# Out:
#   customer_id  income  age  owner education gender  spend
# 0       Cus_1  111000   26      0   College      M  56000
# 1       Cus_2   79000   82      0   College      F  29000
# 2       Cus_3   42000   72      0    Master      F  17000
# 3       Cus_4   83000   54      0    Others      F  24000
# 4       Cus_5   70000   66      0   College      F  26000

# %%
consumers2 = consumers.rename(columns={'gender':'sex'}, inplace=True)
consumers.head()
# Out:
#   customer_id  income  age  owner education sex  spend
# 0       Cus_1  111000   26      0   College   M  56000
# 1       Cus_2   79000   82      0   College   F  29000
# 2       Cus_3   42000   72      0    Master   F  17000
# 3       Cus_4   83000   54      0    Others   F  24000
# 4       Cus_5   70000   66      0   College   F  26000

# %%
consumers = pd.read_csv('consumers_ext.csv')
consumers.head()
# Out:
#   customer_id  income  age  owner education gender  spend
# 0       Cus_1  111000   26      0   College      M  56000
# 1       Cus_2   79000   82      0   College      F  29000
# 2       Cus_3   42000   72      0    Master      F  17000
# 3       Cus_4   83000   54      0    Others      F  24000
# 4       Cus_5   70000   66      0   College      F  26000

# %%
del consumers['owner']
consumers.head()
# Out:
#   customer_id  income  age education gender  spend
# 0       Cus_1  111000   26   College      M  56000
# 1       Cus_2   79000   82   College      F  29000
# 2       Cus_3   42000   72    Master      F  17000
# 3       Cus_4   83000   54    Others      F  24000
# 4       Cus_5   70000   66   College      F  26000

# %%
#pop in inplace operation
consumers_del = consumers.pop('spend')
consumers_del.head()
# Out:
# 0    56000
# 1    29000
# 2    17000
# 3    24000
# 4    26000
# Name: spend, dtype: int64

# %%
consumers.head()
# Out:
#   customer_id  income  age education gender
# 0       Cus_1  111000   26   College      M
# 1       Cus_2   79000   82   College      F
# 2       Cus_3   42000   72    Master      F
# 3       Cus_4   83000   54    Others      F
# 4       Cus_5   70000   66   College      F

# %%
consumers = pd.read_csv('consumers_ext.csv')
consumers.head()
# Out:
#   customer_id  income  age  owner education gender  spend
# 0       Cus_1  111000   26      0   College      M  56000
# 1       Cus_2   79000   82      0   College      F  29000
# 2       Cus_3   42000   72      0    Master      F  17000
# 3       Cus_4   83000   54      0    Others      F  24000
# 4       Cus_5   70000   66      0   College      F  26000

# %%
#drop in not inplace function
consumers_drop = consumers.drop(['age', 'owner'], axis=1)
consumers_drop.head()
# Out:
#   customer_id  income education gender  spend
# 0       Cus_1  111000   College      M  56000
# 1       Cus_2   79000   College      F  29000
# 2       Cus_3   42000    Master      F  17000
# 3       Cus_4   83000    Others      F  24000
# 4       Cus_5   70000   College      F  26000

# %%
consumers.head()
# Out:
#   customer_id  income  age  owner education gender  spend
# 0       Cus_1  111000   26      0   College      M  56000
# 1       Cus_2   79000   82      0   College      F  29000
# 2       Cus_3   42000   72      0    Master      F  17000
# 3       Cus_4   83000   54      0    Others      F  24000
# 4       Cus_5   70000   66      0   College      F  26000

# %%
X = pd.DataFrame(np.array([[0,0,1,8],[6,1,0,0]]), columns=['c1', 'c2','c3','c4'])
Y = pd.DataFrame(np.array([[1,1,3],[2,7,0]]), columns=['a1', 'c3', 'c4'])
print(X)
print(Y)
# Out:
#    c1  c2  c3  c4
# 0   0   0   1   8
# 1   6   1   0   0
#    a1  c3  c4
# 0   1   1   3
# 1   2   7   0

# %%
Z = X.append(Y)
Z
# Out:
# /Users/sadichha/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#     a1   c1   c2  c3  c4
# 0  NaN  0.0  0.0   1   8
# 1  NaN  6.0  1.0   0   0
# 0  1.0  NaN  NaN   1   3
# 1  2.0  NaN  NaN   7   0

# %%
consumers = pd.read_csv('consumers_ext.csv')
consumers1 = consumers.head(5)
consumers1
# Out:
#   customer_id  income  age  owner education gender  spend
# 0       Cus_1  111000   26      0   College      M  56000
# 1       Cus_2   79000   82      0   College      F  29000
# 2       Cus_3   42000   72      0    Master      F  17000
# 3       Cus_4   83000   54      0    Others      F  24000
# 4       Cus_5   70000   66      0   College      F  26000

# %%
consumers2 = consumers.tail(2)
consumers2
# Out:
#      customer_id  income  age  owner education gender  spend
# 1875    Cus_1897   40000   62      0  Bachelor      M  24000
# 1876    Cus_1898  113000   69      0  Bachelor      F  39000

# %%
p3 = consumers1.append(consumers2)
p3
# Out:
#      customer_id  income  age  owner education gender  spend
# 0          Cus_1  111000   26      0   College      M  56000
# 1          Cus_2   79000   82      0   College      F  29000
# 2          Cus_3   42000   72      0    Master      F  17000
# 3          Cus_4   83000   54      0    Others      F  24000
# 4          Cus_5   70000   66      0   College      F  26000
# 1875    Cus_1897   40000   62      0  Bachelor      M  24000
# 1876    Cus_1898  113000   69      0  Bachelor      F  39000

# %%
p3 = pd.concat([consumers1, consumers2], axis=0)
p3
# Out:
#      customer_id  income  age  owner education gender  spend
# 0          Cus_1  111000   26      0   College      M  56000
# 1          Cus_2   79000   82      0   College      F  29000
# 2          Cus_3   42000   72      0    Master      F  17000
# 3          Cus_4   83000   54      0    Others      F  24000
# 4          Cus_5   70000   66      0   College      F  26000
# 1875    Cus_1897   40000   62      0  Bachelor      M  24000
# 1876    Cus_1898  113000   69      0  Bachelor      F  39000

# %%
consumers = pd.read_csv('consumers_ext.csv')
consumers.head()
# Out:
#   customer_id  income  age  owner education gender  spend
# 0       Cus_1  111000   26      0   College      M  56000
# 1       Cus_2   79000   82      0   College      F  29000
# 2       Cus_3   42000   72      0    Master      F  17000
# 3       Cus_4   83000   54      0    Others      F  24000
# 4       Cus_5   70000   66      0   College      F  26000

# %%
S = consumers.gender == 'F'
S
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8       False
# 9       False
# 10      False
# 11       True
# 12       True
# 13       True
# 14       True
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20       True
# 21      False
# 22      False
# 23      False
# 24       True
# 25       True
# 26      False
# 27      False
# 28       True
# 29       True
#         ...
# 1847    False
# 1848     True
# 1849    False
# 1850     True
# 1851    False
# 1852     True
# 1853    False
# 1854    False
# 1855    False
# 1856     True
# 1857     True
# 1858    False
# 1859    False
# 1860     True
# 1861     True
# 1862    False
# 1863     True
# 1864     True
# 1865     True
# 1866    False
# 1867     True
# 1868     True
# 1869    False
# 1870    False
# 1871     True
# 1872    False
# 1873     True
# 1874     True
# 1875    False
# 1876     True
# ...

# %%
X = consumers[S]
X
# Out:
#      customer_id  income  age  owner education gender  spend
# 1          Cus_2   79000   82      0   College      F  29000
# 2          Cus_3   42000   72      0    Master      F  17000
# 3          Cus_4   83000   54      0    Others      F  24000
# 4          Cus_5   70000   66      0   College      F  26000
# 5          Cus_6   98000   65      0    Others      F  19000
# 6          Cus_7   95000   28      0    Others      F  25000
# 7          Cus_8   79000   80      0    Others      F  45000
# 11        Cus_12  113000   54      0    Others      F  24000
# 12        Cus_13   41000   56      0    Master      F   2000
# 13        Cus_14   66000   82      1  Bachelor      F  67000
# 14        Cus_15   98000   63      0   College      F  36000
# 18        Cus_19   84000   44      0   College      F  40000
# 20        Cus_21   55000   79      0    Master      F  23000
# 24        Cus_25  114000   36      0  Bachelor      F  55000
# ...

# %%
S = consumers['income'] - consumers['spend'] >60000
S
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5        True
# 6        True
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14       True
# 15      False
# 16      False
# 17       True
# 18      False
# 19       True
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25       True
# 26       True
# 27      False
# 28      False
# 29       True
#         ...
# 1847    False
# 1848    False
# 1849    False
# 1850    False
# 1851     True
# 1852     True
# 1853    False
# 1854    False
# 1855    False
# 1856     True
# 1857     True
# 1858     True
# 1859    False
# 1860    False
# 1861    False
# 1862    False
# 1863    False
# 1864    False
# 1865    False
# 1866    False
# 1867     True
# 1868    False
# 1869    False
# 1870    False
# 1871    False
# 1872    False
# 1873     True
# 1874     True
# 1875    False
# 1876     True
# ...

# %%
X = consumers[S]
X.head(3)
# Out:
#    customer_id  income  age  owner education gender  spend
# 5        Cus_6   98000   65      0    Others      F  19000
# 6        Cus_7   95000   28      0    Others      F  25000
# 11      Cus_12  113000   54      0    Others      F  24000

# %%
consumers = pd.read_csv('consumers_ext.csv', index_col='customer_id')
consumers.head()
# Out:
#              income  age  owner education gender  spend
# customer_id
# Cus_1        111000   26      0   College      M  56000
# Cus_2         79000   82      0   College      F  29000
# Cus_3         42000   72      0    Master      F  17000
# Cus_4         83000   54      0    Others      F  24000
# Cus_5         70000   66      0   College      F  26000

# %%
consumers.loc['Cus_3', 'gender'] ='M'
consumers.head()
# Out:
#              income  age  owner education gender  spend
# customer_id
# Cus_1        111000   26      0   College      M  56000
# Cus_2         79000   82      0   College      F  29000
# Cus_3         42000   72      0    Master      M  17000
# Cus_4         83000   54      0    Others      F  24000
# Cus_5         70000   66      0   College      F  26000

# %%
consumers.iloc[3,4] = 'M'
consumers.head()
# Out:
#              income  age  owner education gender  spend
# customer_id
# Cus_1        111000   26      0   College      M  56000
# Cus_2         79000   82      0   College      F  29000
# Cus_3         42000   72      0    Master      M  17000
# Cus_4         83000   54      0         M      M  24000
# Cus_5         70000   66      0   College      F  26000
