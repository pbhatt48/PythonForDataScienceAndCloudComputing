# %%
import numpy as np
import pandas as pd

# %%
df_main = pd.read_csv('mental-health-in-tech-survey.csv', na_values='NaN')
df_main
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
not_correc_age = df_main[(df_main.Age >150) | (df_main.Age < 0)]
not_correc_age
# Out:
#                 Timestamp          Age Gender         Country state  \
# 143   2014-08-27 12:39:14          -29   Male   United States    MN
# 364   2014-08-27 15:05:21          329   Male   United States    OH
# 390   2014-08-27 15:24:47  99999999999    All        Zimbabwe   NaN
# 715   2014-08-28 10:07:53        -1726   male  United Kingdom   NaN
# 1127  2014-08-30 20:55:11           -1      p   United States    AL
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 143             No             No        No            NaN  More than 1000
# 364             No             No       Yes          Often            6-25
# 390            Yes            Yes       Yes          Often             1-5
# 715             No             No       Yes      Sometimes          26-100
# 1127           Yes            Yes       Yes          Often             1-5
#
#       ...               leave mental_health_consequence  \
# ...

# %%
correc_age = df_main[(df_main.Age <=150) & (df_main.Age >= 0)]
len(correc_age)
# Out:
# 1254

# %%
age10 = correc_age[(correc_age.Age <10) & (correc_age.Age >= 0)]
age20 = correc_age[(correc_age.Age <20) & (correc_age.Age >= 10)]
age30 = correc_age[(correc_age.Age <30) & (correc_age.Age >= 20)]
age40 = correc_age[(correc_age.Age <40) & (correc_age.Age >= 30)]
age50 = correc_age[(correc_age.Age <50) & (correc_age.Age >= 40)]
age60 = correc_age[(correc_age.Age <60) & (correc_age.Age >= 50)]
age70 = correc_age[(correc_age.Age <70) & (correc_age.Age >= 60)]
age80 = correc_age[(correc_age.Age <80) & (correc_age.Age >= 70)]
print(len(age10), len(age20), len(age30), len(age40), len(age50), len(age60), len(age70), len(age80)  )
# Out:
# 2 17 500 554 149 26 5 1

# %%
age10n = correc_age[(correc_age.Age <10) & (correc_age.Age >= 0) & (correc_age.treatment == 'No')]
age20n = correc_age[(correc_age.Age <20) & (correc_age.Age >= 10)& (correc_age.treatment == 'No')]
age30n = correc_age[(correc_age.Age <30) & (correc_age.Age >= 20)& (correc_age.treatment == 'No')]
age40n = correc_age[(correc_age.Age <40) & (correc_age.Age >= 30)& (correc_age.treatment == 'No')]
age50n = correc_age[(correc_age.Age <50) & (correc_age.Age >= 40)& (correc_age.treatment == 'No')]
age60n = correc_age[(correc_age.Age <60) & (correc_age.Age >= 50)& (correc_age.treatment == 'No')]
age70n = correc_age[(correc_age.Age <70) & (correc_age.Age >= 60)& (correc_age.treatment == 'No')]
age80n = correc_age[(correc_age.Age <80) & (correc_age.Age >= 70)& (correc_age.treatment == 'No')]

print(len(age10n), len(age20n), len(age30n), len(age40n), len(age50n), len(age60n), len(age70n), len(age80n)  )
# Out:
# 1 10 265 269 62 11 3 0

# %%
age10y = correc_age[(correc_age.Age <10) & (correc_age.Age >= 0) & (correc_age.treatment == 'Yes')]
age20y = correc_age[(correc_age.Age <20) & (correc_age.Age >= 10)& (correc_age.treatment == 'Yes')]
age30y = correc_age[(correc_age.Age <30) & (correc_age.Age >= 20)& (correc_age.treatment == 'Yes')]
age40y = correc_age[(correc_age.Age <40) & (correc_age.Age >= 30)& (correc_age.treatment == 'Yes')]
age50y = correc_age[(correc_age.Age <50) & (correc_age.Age >= 40)& (correc_age.treatment == 'Yes')]
age60y = correc_age[(correc_age.Age <60) & (correc_age.Age >= 50)& (correc_age.treatment == 'Yes')]
age70y = correc_age[(correc_age.Age <70) & (correc_age.Age >= 60)& (correc_age.treatment == 'Yes')]
age80y = correc_age[(correc_age.Age <80) & (correc_age.Age >= 70)& (correc_age.treatment == 'Yes')]


print(len(age10y), len(age20y), len(age30y), len(age40y), len(age50y), len(age60y), len(age70y), len(age80y)  )
# Out:
# 1 7 235 285 87 15 2 1

# %%
age20y = correc_age[(correc_age.Age <20) & (correc_age.Age >= 0) & (correc_age.mental_health_consequence == 'Yes')]
age40y = correc_age[(correc_age.Age <40) & (correc_age.Age >= 20)& (correc_age.mental_health_consequence == 'Yes')]
age60y = correc_age[(correc_age.Age <60) & (correc_age.Age >= 40)& (correc_age.mental_health_consequence == 'Yes')]
age80y = correc_age[(correc_age.Age <80) & (correc_age.Age >= 60)& (correc_age.mental_health_consequence == 'Yes')]

print(len(age20y),len(age40y), len(age60y), len(age80y) )
# Out:
# 6 233 49 1

# %%
age20n = correc_age[(correc_age.Age <20) & (correc_age.Age >= 0) & (correc_age.mental_health_consequence == 'No')]
age40n = correc_age[(correc_age.Age <40) & (correc_age.Age >= 20)& (correc_age.mental_health_consequence == 'No')]
age60n = correc_age[(correc_age.Age <60) & (correc_age.Age >= 40)& (correc_age.mental_health_consequence == 'No')]
age80n = correc_age[(correc_age.Age <80) & (correc_age.Age >= 60)& (correc_age.mental_health_consequence == 'No')]

print(len(age20n),len(age40n), len(age60n), len(age80n) )
# Out:
# 9 423 56 1

# %%
age20m = correc_age[(correc_age.Age <20) & (correc_age.Age >= 0) & (correc_age.mental_health_consequence == 'Maybe')]
age40m = correc_age[(correc_age.Age <40) & (correc_age.Age >= 20)& (correc_age.mental_health_consequence == 'Maybe')]
age60m = correc_age[(correc_age.Age <60) & (correc_age.Age >= 40)& (correc_age.mental_health_consequence == 'Maybe')]
age80m = correc_age[(correc_age.Age <80) & (correc_age.Age >= 60)& (correc_age.mental_health_consequence == 'Maybe')]

print(len(age20m),len(age40m), len(age60m), len(age80m) )
# Out:
# 4 398 70 4

# %%
###physical health consequence
age20y = correc_age[(correc_age.Age <20) & (correc_age.Age >= 0) & (correc_age.phys_health_consequence == 'Yes')]
age40y = correc_age[(correc_age.Age <40) & (correc_age.Age >= 20)& (correc_age.phys_health_consequence == 'Yes')]
age60y = correc_age[(correc_age.Age <60) & (correc_age.Age >= 40)& (correc_age.phys_health_consequence == 'Yes')]
age80y = correc_age[(correc_age.Age <80) & (correc_age.Age >= 60)& (correc_age.phys_health_consequence == 'Yes')]

print(len(age20y),len(age40y), len(age60y), len(age80y) )
# Out:
# 2 46 11 0

# %%
age20n = correc_age[(correc_age.Age <20) & (correc_age.Age >= 0) & (correc_age.phys_health_consequence == 'No')]
age40n = correc_age[(correc_age.Age <40) & (correc_age.Age >= 20)& (correc_age.phys_health_consequence == 'No')]
age60n = correc_age[(correc_age.Age <60) & (correc_age.Age >= 40)& (correc_age.phys_health_consequence == 'No')]
age80n = correc_age[(correc_age.Age <80) & (correc_age.Age >= 60)& (correc_age.phys_health_consequence == 'No')]

print(len(age20n),len(age40n), len(age60n), len(age80n) )
# Out:
# 13 791 115 3

# %%
age20m = correc_age[(correc_age.Age <20) & (correc_age.Age >= 0) & (correc_age.phys_health_consequence == 'Maybe')]
age40m = correc_age[(correc_age.Age <40) & (correc_age.Age >= 20)& (correc_age.phys_health_consequence == 'Maybe')]
age60m = correc_age[(correc_age.Age <60) & (correc_age.Age >= 40)& (correc_age.phys_health_consequence == 'Maybe')]
age80m = correc_age[(correc_age.Age <80) & (correc_age.Age >= 60)& (correc_age.phys_health_consequence == 'Maybe')]

print(len(age20m),len(age40m), len(age60m), len(age80m) )
# Out:
# 4 217 49 3

# %%
male_pop = male_pop = df_main[(df_main.Gender.str.lower() == "male") | (df_main.Gender.str.lower() == "m") | (df_main.Gender.str.lower() == "maile") | (df_main.Gender.str.lower() == "mal")|  (df_main.Gender.str.lower() == "mal ")| (df_main.Gender.str.lower() == "man") | (df_main.Gender.str.lower() == "msle")| (df_main.Gender.str.lower() == "mail") | (df_main.Gender.str.lower() == "malr")]
male_pop
# Out:
#                 Timestamp  Age Gender         Country state self_employed  \
# 1     2014-08-27 11:29:37   44      M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32   Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31   Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31   Male   United States    TX           NaN
# 5     2014-08-27 11:31:22   33   Male   United States    TN           NaN
# ...                   ...  ...    ...             ...   ...           ...
# 1253  2015-08-25 19:59:38   36   Male   United States    UT            No
# 1254  2015-09-12 11:17:21   26   male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34   male   United States    CA            No
# 1258  2016-02-01 23:04:31   25   Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
len(male_pop[male_pop.treatment == "Yes"]), len(male_pop[male_pop.treatment == "No"])
# Out:
# (441, 537)

# %%
female_pop = df_main[(df_main.Gender.str.lower() == "female") | (df_main.Gender.str.lower() == "f") | (df_main.Gender.str.lower() == "woman") | (df_main.Gender.str.lower() == "femake")| (df_main.Gender.str.lower() == "femail")]
female_pop
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 6     2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 8     2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 12    2014-08-27 11:33:23   42  female   United States    CA           NaN
# 15    2014-08-27 11:34:00   29  female   United States    IL           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1230  2015-02-24 08:54:35   23  Female  United Kingdom   NaN            No
# 1243  2015-05-05 14:22:18   43       f   United States    FL            No
# 1244  2015-05-05 15:16:25   32  female  United Kingdom   NaN            No
# 1248  2015-06-25 12:24:31   41  Female   United States    WA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
len(female_pop[female_pop.treatment == "Yes"]), len(female_pop[female_pop.treatment == "No"])
# Out:
# (167, 75)

# %%
len(male_pop[male_pop.treatment == "Yes"]), len(male_pop[male_pop.treatment == "No"])
# Out:
# (441, 537)

# %%
len(female_pop[female_pop.mental_health_consequence == "Yes"]), len(female_pop[female_pop.mental_health_consequence == "No"]), len(female_pop[female_pop.mental_health_consequence == "Maybe"])
# Out:
# (64, 72, 106)

# %%
len(male_pop[male_pop.mental_health_consequence == "Yes"]), len(male_pop[male_pop.mental_health_consequence == "No"]) , len(male_pop[male_pop.mental_health_consequence == "Maybe"])
# Out:
# (210, 412, 356)

# %%
len(female_pop[female_pop.phys_health_consequence == "Yes"]), len(female_pop[female_pop.phys_health_consequence == "No"]), len(female_pop[female_pop.phys_health_consequence == "Maybe"])
# Out:
# (15, 162, 65)

# %%
len(male_pop[male_pop.phys_health_consequence == "Yes"]), len(male_pop[male_pop.phys_health_consequence == "No"]) , len(male_pop[male_pop.phys_health_consequence == "Maybe"])
# Out:
# (41, 745, 192)

# %%
df_main.Country.unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Russia', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica',
#        'Austria', 'Ireland', 'India', 'South Africa', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand',
#        'Zimbabwe', 'Spain', 'Finland', 'Uruguay', 'Israel',
#        'Bosnia and Herzegovina', 'Hungary', 'Singapore', 'Japan',
#        'Nigeria', 'Croatia', 'Norway', 'Thailand', 'Denmark',
#        'Bahamas, The', 'Greece', 'Moldova', 'Georgia', 'China',
#        'Czech Republic', 'Philippines'], dtype=object)

# %%
us = df_main[df_main.Country == "United States"]
uk = df_main[df_main.Country == "United Kingdom"]
canada = df_main[df_main.Country == "Canada"]
others = df_main[(df_main.Country != "United States") & (df_main.Country != "Canada") & (df_main.Country != "United Kingdom")]
len(us) + len(uk) + len(canada) + len(others), len(df_main)
# Out:
# (1259, 1259)

# %%
us_treatment_y = us[us.treatment == "Yes"]
us_treatment_n = us[us.treatment == "No"]
len(us_treatment_y), len(us_treatment_n)
# Out:
# (410, 341)

# %%
uk_treatment_y = uk[uk.treatment == "Yes"]
uk_treatment_n = uk[uk.treatment == "No"]
len(uk_treatment_y), len(uk_treatment_n)
# Out:
# (93, 92)

# %%
c_treatment_y = canada[canada.treatment == "Yes"]
c_treatment_n = canada[canada.treatment == "No"]
len(c_treatment_y), len(c_treatment_n)
# Out:
# (37, 35)

# %%
o_treatment_y = others[others.treatment == "Yes"]
o_treatment_n = others[others.treatment == "No"]
len(o_treatment_y), len(o_treatment_n)
# Out:
# (97, 154)

# %%
us = df_main[df_main.Country == "United States"]
uk = df_main[df_main.Country == "United Kingdom"]
c = df_main[df_main.Country == "Canada"]
o = df_main[(df_main.Country != "United States") & (df_main.Country != "Canada") & (df_main.Country != "United Kingdom")]
len(us) + len(uk) + len(c) + len(o), len(df_main)
# Out:
# (1259, 1259)

# %%
us_ment_y = us[us.mental_health_consequence == "Yes"]
us_ment_n = us[us.mental_health_consequence == "No"]
us_ment_m = us[us.mental_health_consequence == "Maybe"]
len(us_ment_y), len(us_ment_n),len(us_ment_m)
# Out:
# (171, 280, 300)

# %%
uk_ment_y = uk[uk.mental_health_consequence == "Yes"]
uk_ment_n = uk[uk.mental_health_consequence == "No"]
uk_ment_m = uk[uk.mental_health_consequence == "Maybe"]
len(uk_ment_y), len(uk_ment_n),len(uk_ment_m)
# Out:
# (43, 69, 73)

# %%
c_ment_y = c[c.mental_health_consequence == "Yes"]
c_ment_n = c[c.mental_health_consequence == "No"]
c_ment_m = c[c.mental_health_consequence == "Maybe"]
len(c_ment_y), len(c_ment_n),len(c_ment_m)
# Out:
# (16, 31, 25)

# %%
o_ment_y = o[o.mental_health_consequence == "Yes"]
o_ment_n = o[o.mental_health_consequence == "No"]
o_ment_m = o[o.mental_health_consequence == "Maybe"]
len(o_ment_y), len(o_ment_n),len(o_ment_m)
# Out:
# (62, 110, 79)

# %%
#####
us_phy_y = us[us.phys_health_consequence == "Yes"]
us_phy_n = us[us.phys_health_consequence == "No"]
us_phy_m = us[us.phys_health_consequence == "Maybe"]
len(us_phy_y), len(us_phy_n),len(us_phy_m)
# Out:
# (30, 571, 150)

# %%
uk_phy_y = uk[uk.phys_health_consequence == "Yes"]
uk_phy_n = uk[uk.phys_health_consequence == "No"]
uk_phy_m = uk[uk.phys_health_consequence == "Maybe"]
len(uk_phy_y), len(uk_phy_n),len(uk_phy_m)
# Out:
# (10, 121, 54)

# %%
canada_phy_y = canada[canada.phys_health_consequence == "Yes"]
canada_phy_n = canada[canada.phys_health_consequence == "No"]
canada_phy_m = canada[canada.phys_health_consequence == "Maybe"]
len(canada_phy_y), len(canada_phy_n),len(canada_phy_m)
# Out:
# (2, 56, 14)

# %%
others_phy_y = others[others.phys_health_consequence == "Yes"]
others_phy_n = others[others.phys_health_consequence == "No"]
others_phy_m = others[others.phys_health_consequence == "Maybe"]
len(others_phy_y), len(others_phy_n),len(others_phy_m)
# Out:
# (19, 177, 55)

# %%
df_main.Country.value_counts()
# Out:
# United States             751
# United Kingdom            185
# Canada                     72
# Germany                    45
# Netherlands                27
# Ireland                    27
# Australia                  21
# France                     13
# India                      10
# New Zealand                 8
# Italy                       7
# Switzerland                 7
# Sweden                      7
# Poland                      7
# South Africa                6
# Belgium                     6
# Brazil                      6
# Israel                      5
# Bulgaria                    4
# Singapore                   4
# Austria                     3
# Finland                     3
# Mexico                      3
# Russia                      3
# Colombia                    2
# Portugal                    2
# Greece                      2
# Croatia                     2
# Denmark                     2
# Uruguay                     1
# Thailand                    1
# ...

# %%
## famil his and treatment
fam_y = df_main[df_main.family_history == "Yes"]
fam_n = df_main[df_main.family_history == "No"]

# %%
fam_hy_yt = fam_y[fam_y.treatment == "Yes"]
fam_hy_nt = fam_y[fam_y.treatment == "No"]
len(fam_hy_yt), len(fam_hy_nt)
# Out:
# (365, 127)

# %%
fam_hn_yt = fam_n[fam_n.treatment == "Yes"]
fam_hn_nt = fam_n[fam_n.treatment == "No"]
len(fam_hn_yt), len(fam_hn_nt)
# Out:
# (272, 495)

# %%
fam_ment_y = fam_y[fam_y.mental_health_consequence == "Yes"]
fam_ment_n = fam_y[fam_y.mental_health_consequence == "No"]
fam_ment_m = fam_y[fam_y.mental_health_consequence == "Maybe"]
len(fam_ment_y) , len(fam_ment_n), len(fam_ment_m)
# Out:
# (134, 165, 193)

# %%
fam_ment_y = fam_n[fam_n.mental_health_consequence == "Yes"]
fam_ment_n = fam_n[fam_n.mental_health_consequence == "No"]
fam_ment_m = fam_n[fam_n.mental_health_consequence == "Maybe"]
len(fam_ment_y) , len(fam_ment_n), len(fam_ment_m)
# Out:
# (158, 325, 284)

# %%
fam_phy_y = fam_y[fam_y.phys_health_consequence == "Yes"]
fam_phy_n = fam_y[fam_y.phys_health_consequence == "No"]
fam_phy_m = fam_y[fam_y.phys_health_consequence == "Maybe"]
len(fam_phy_y) , len(fam_phy_n), len(fam_phy_m)
# Out:
# (31, 348, 113)

# %%
fam_phy_y = fam_n[fam_n.phys_health_consequence == "Yes"]
fam_phy_n = fam_n[fam_n.phys_health_consequence == "No"]
fam_phy_m = fam_n[fam_n.phys_health_consequence == "Maybe"]
len(fam_phy_y) , len(fam_phy_n), len(fam_phy_m)
# Out:
# (30, 577, 160)

# %%
len(fam_phy_y) + len(fam_phy_n)+ len(fam_phy_m) + len(fam_phy_y) +  len(fam_phy_n) + len(fam_phy_m)
# Out:
# 1534

# %%
#66
correc_age = df_main[(df_main.Age <=150) & (df_main.Age >= 0)]
correc_age
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
correc_age_sam = correc_age.sample(n=627)
correc_age_sam
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 689   2014-08-28 09:54:21   27       f  United Kingdom   NaN            No
# 462   2014-08-27 16:01:52   28    Make   United States    UT            No
# 883   2014-08-28 17:23:19   36    male   United States    VA           Yes
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 178   2014-08-27 12:51:25   45       F   United States    CA            No
# ...                   ...  ...     ...             ...   ...           ...
# 916   2014-08-28 19:04:05   30    Male   United States    PA           Yes
# 74    2014-08-27 11:56:29   33    Male   United States    CA            No
# 673   2014-08-28 08:00:40   26  female          Israel   NaN            No
# 48    2014-08-27 11:43:56   26       m          Canada   NaN           Yes
# 1216  2015-02-21 09:30:14   27    Male  United Kingdom   NaN            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
age20y = correc_age_sam[(correc_age_sam.Age <20) & (correc_age_sam.Age >= 0) & (correc_age_sam.mental_health_consequence == 'Yes')]
age40y = correc_age_sam[(correc_age_sam.Age <40) & (correc_age_sam.Age >= 20)& (correc_age_sam.mental_health_consequence == 'Yes')]
age60y = correc_age_sam[(correc_age_sam.Age <60) & (correc_age_sam.Age >= 40)& (correc_age_sam.mental_health_consequence == 'Yes')]
age80y = correc_age_sam[(correc_age_sam.Age <80) & (correc_age_sam.Age >= 60)& (correc_age_sam.mental_health_consequence == 'Yes')]

print(len(age20y),len(age40y), len(age60y), len(age80y) )
# Out:
# 2 122 24 1

# %%
age20n = correc_age_sam[(correc_age_sam.Age <20) & (correc_age_sam.Age >= 0) & (correc_age_sam.mental_health_consequence == 'No')]
age40n = correc_age_sam[(correc_age_sam.Age <40) & (correc_age_sam.Age >= 20)& (correc_age_sam.mental_health_consequence == 'No')]
age60n = correc_age_sam[(correc_age_sam.Age <60) & (correc_age_sam.Age >= 40)& (correc_age_sam.mental_health_consequence == 'No')]
age80n = correc_age_sam[(correc_age_sam.Age <80) & (correc_age_sam.Age >= 60)& (correc_age_sam.mental_health_consequence == 'No')]

print(len(age20n),len(age40n), len(age60n), len(age80n) )
# Out:
# 6 200 29 1

# %%
age20m = correc_age_sam[(correc_age_sam.Age <20) & (correc_age_sam.Age >= 0) & (correc_age_sam.mental_health_consequence == 'Maybe')]
age40m = correc_age_sam[(correc_age_sam.Age <40) & (correc_age_sam.Age >= 20)& (correc_age_sam.mental_health_consequence == 'Maybe')]
age60m = correc_age_sam[(correc_age_sam.Age <60) & (correc_age_sam.Age >= 40)& (correc_age_sam.mental_health_consequence == 'Maybe')]
age80m = correc_age_sam[(correc_age_sam.Age <80) & (correc_age_sam.Age >= 60)& (correc_age_sam.mental_health_consequence == 'Maybe')]

print(len(age20m),len(age40m), len(age60m), len(age80m) )
# Out:
# 3 206 32 1

# %%
tage20y = correc_age_sam[(correc_age_sam.Age <20) & (correc_age_sam.Age >= 0) & (correc_age_sam.treatment == 'Yes')]
tage40y = correc_age_sam[(correc_age_sam.Age <40) & (correc_age_sam.Age >= 20)& (correc_age_sam.treatment == 'Yes')]
tage60y = correc_age_sam[(correc_age_sam.Age <60) & (correc_age_sam.Age >= 40)& (correc_age_sam.treatment == 'Yes')]
tage80y = correc_age_sam[(correc_age_sam.Age <80) & (correc_age_sam.Age >= 60)& (correc_age_sam.treatment == 'Yes')]

print(len(tage20y),len(tage40y), len(tage60y), len(tage80y) )
# Out:
# 4 274 56 1

# %%
tnage20y = correc_age_sam[(correc_age_sam.Age <20) & (correc_age_sam.Age >= 0) & (correc_age_sam.treatment == 'No')]
tnage40y = correc_age_sam[(correc_age_sam.Age <40) & (correc_age_sam.Age >= 20)& (correc_age_sam.treatment == 'No')]
tnage60y = correc_age_sam[(correc_age_sam.Age <60) & (correc_age_sam.Age >= 40)& (correc_age_sam.treatment == 'No')]
tnage80y = correc_age_sam[(correc_age_sam.Age <80) & (correc_age_sam.Age >= 60)& (correc_age_sam.treatment == 'No')]

print(len(tnage20y),len(tnage40y), len(tnage60y), len(tnage80y) )
# Out:
# 7 254 29 2

# %%
len(df_main.columns), len(df_main)
# Out:
# (27, 1259)

# %%
correc_age
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...
