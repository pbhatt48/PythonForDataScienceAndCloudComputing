# %%
import numpy as np
import pandas as pd

# %%
record1=[['John', 19, 'M', 88], ['Marry', 20, 'F', 75] , ['Jack', 22, 'M', 63] , ['Jane', 20, 'F', 91]]
titles1=['student', 'age', 'gender', 'mark']
record2=[['Larry', 'M', 321061] , ['Jack', 'M', 301901] , ['Marry', 'F', 108901]]
titles2=['student', 'gender', 'post']
student1 = pd.DataFrame(record1, columns=titles1)
student2 = pd.DataFrame(record2, columns=titles2)
print(student1)
print(student2)
# Out:
#   student  age gender  mark
# 0    John   19      M    88
# 1   Marry   20      F    75
# 2    Jack   22      M    63
# 3    Jane   20      F    91
#   student gender    post
# 0   Larry      M  321061
# 1    Jack      M  301901
# 2   Marry      F  108901

# %%
pd.concat([student1, student2], axis=0)
# Out:
# /Users/sadichha/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     age gender  mark      post student
# 0  19.0      M  88.0       NaN    John
# 1  20.0      F  75.0       NaN   Marry
# 2  22.0      M  63.0       NaN    Jack
# 3  20.0      F  91.0       NaN    Jane
# 0   NaN      M   NaN  321061.0   Larry
# 1   NaN      M   NaN  301901.0    Jack
# 2   NaN      F   NaN  108901.0   Marry

# %%
pd.concat([student1, student2],axis=1)
# Out:
#   student  age gender  mark student gender      post
# 0    John   19      M    88   Larry      M  321061.0
# 1   Marry   20      F    75    Jack      M  301901.0
# 2    Jack   22      M    63   Marry      F  108901.0
# 3    Jane   20      F    91     NaN    NaN       NaN

# %%
df = pd.read_csv('people_miss.csv')
df.head()
# Out:
#    id     name                    email   age  entrydate gender  spend  \
# 0   1     glen          glent@gmail.com  23.0   19650409      M  462.0
# 1   2  Yinging      yirmic302@gmail.com  24.0   20070611      F  215.0
# 2   3   Lendor       kude1035@gmail.com  45.0   19900905      M  185.0
# 3   4  Rickina         RK023781@aol.com  24.0   19850110      F  800.0
# 4   5  Tomocro  troman.telcon@gmail.com   NaN   19970819      M   46.0
#
#    upperlimit   income education
# 0       714.0  23113.3         U
# 1       571.0  20000.0         C
# 2      1000.0  72000.0         U
# 3       714.0      0.0         H
# 4       857.0  35000.0         C

# %%
df1 = df[['id', 'name', 'email']].head()
df2 = df[['id', 'gender', 'income']].head(8)
df1
# Out:
#    id     name                    email
# 0   1     glen          glent@gmail.com
# 1   2  Yinging      yirmic302@gmail.com
# 2   3   Lendor       kude1035@gmail.com
# 3   4  Rickina         RK023781@aol.com
# 4   5  Tomocro  troman.telcon@gmail.com

# %%
df2
# Out:
#    id gender   income
# 0   1      M  23113.3
# 1   2      F  20000.0
# 2   3      M  72000.0
# 3   4      F      0.0
# 4   5      M  35000.0
# 5   6      M      0.0
# 6   7      F  90000.0
# 7   8      M      NaN

# %%
merge_inner = pd.merge(df1, df2, on='id', how='inner')
merge_inner
# Out:
#    id     name                    email gender   income
# 0   1     glen          glent@gmail.com      M  23113.3
# 1   2  Yinging      yirmic302@gmail.com      F  20000.0
# 2   3   Lendor       kude1035@gmail.com      M  72000.0
# 3   4  Rickina         RK023781@aol.com      F      0.0
# 4   5  Tomocro  troman.telcon@gmail.com      M  35000.0

# %%
merge_outer = pd.merge(df1, df2, on='id', how='outer')
merge_outer
# Out:
#    id     name                    email gender   income
# 0   1     glen          glent@gmail.com      M  23113.3
# 1   2  Yinging      yirmic302@gmail.com      F  20000.0
# 2   3   Lendor       kude1035@gmail.com      M  72000.0
# 3   4  Rickina         RK023781@aol.com      F      0.0
# 4   5  Tomocro  troman.telcon@gmail.com      M  35000.0
# 5   6      NaN                      NaN      M      0.0
# 6   7      NaN                      NaN      F  90000.0
# 7   8      NaN                      NaN      M      NaN

# %%
X = pd.DataFrame(np.array([[0,0,1],[6,1,0]]), columns=['c1','c2','c3'])
Y = pd.DataFrame(np.array([[0,1,3],[6,7,0]]), columns=['c1','c3','c4'])
X
# Out:
#    c1  c2  c3
# 0   0   0   1
# 1   6   1   0

# %%
Y
# Out:
#    c1  c3  c4
# 0   0   1   3
# 1   6   7   0

# %%
pd.merge(X,Y)
# Out:
#    c1  c2  c3  c4
# 0   0   0   1   3

# %%
X = pd.DataFrame(np.array([[0,0],[6,1]]), columns=['a1','a2'])
Y = pd.DataFrame(np.array([[0,1],[6,7],[1,5]]), columns=['b1','b2'])
X
# Out:
#    a1  a2
# 0   0   0
# 1   6   1

# %%
Y
# Out:
#    b1  b2
# 0   0   1
# 1   6   7
# 2   1   5

# %%
z1= X.join(Y, lsuffix=['a1','a2'], rsuffix=['b1','b2'])
z1
# Out:
#    a1  a2  b1  b2
# 0   0   0   0   1
# 1   6   1   6   7

# %%
z1= X.join(Y, lsuffix=['a1','a2'], rsuffix=['b1','b2'], how='outer')
z1
# Out:
#     a1   a2  b1  b2
# 0  0.0  0.0   0   1
# 1  6.0  1.0   6   7
# 2  NaN  NaN   1   5

# %%
record1=[['John', 19, 'M', 88], ['Marry', 20, 'F', 75] , ['Jack', 22, 'M', 63] , ['Jane', 20, 'F', 91]]
titles1=['student', 'age', 'gender', 'mark']
record2=[['Larry', 'M', 321061] , ['Jack', 'M', 301901] , ['Marry', 'F', 108901]]
titles2=['student', 'gender', 'post']

# %%
df1 = pd.DataFrame(record1, columns=titles1)
df1
# Out:
#   student  age gender  mark
# 0    John   19      M    88
# 1   Marry   20      F    75
# 2    Jack   22      M    63
# 3    Jane   20      F    91

# %%
df2 = pd.DataFrame(record2, columns=titles2)
df2
# Out:
#   student gender    post
# 0   Larry      M  321061
# 1    Jack      M  301901
# 2   Marry      F  108901

# %%
pd.concat([df1, df2], axis=1)
# Out:
#   student  age gender  mark student gender      post
# 0    John   19      M    88   Larry      M  321061.0
# 1   Marry   20      F    75    Jack      M  301901.0
# 2    Jack   22      M    63   Marry      F  108901.0
# 3    Jane   20      F    91     NaN    NaN       NaN

# %%
pd.concat([df1, df2], axis=0)
# Out:
# /Users/sadichha/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     age gender  mark      post student
# 0  19.0      M  88.0       NaN    John
# 1  20.0      F  75.0       NaN   Marry
# 2  22.0      M  63.0       NaN    Jack
# 3  20.0      F  91.0       NaN    Jane
# 0   NaN      M   NaN  321061.0   Larry
# 1   NaN      M   NaN  301901.0    Jack
# 2   NaN      F   NaN  108901.0   Marry

# %%
people_prof = pd.read_csv('people_prof.csv', na_values='NA')
people_prof.head()
# Out:
#       name                    email  age  entrydate gender  target
# 0     Glen          glent@gmail.com   23   19650409      M       0
# 1  Yinging      yirmic302@gmail.com   24   20070611      F       1
# 2   Lendor       kude1035@gmail.com   45   19900905      M       0
# 3  Tomocro  troman.telcon@gmail.com   27   19970819      M       1
# 4    Keren  tl.nesleeza@hotmail.com   58   19550902      M       0

# %%
people_fin = pd.read_csv('people_fin.csv', na_values="NA")
people_fin.head()
# Out:
#                      email  amount  upperlevel   income education
# 0          glent@gmail.com     462         714  23113.3         U
# 1      yirmic302@gmail.com     215         571  20000.0         C
# 2       kude1035@gmail.com     185        1000  72000.0         C
# 3  troman.telcon@gmail.com      46         857  35000.0         C
# 4  tl.nesleeza@hotmail.com    1000         429  72000.0         U

# %%
merge_inner = pd.merge(people_prof, people_fin, on='email', how='inner')
merge_inner.shape
# Out:
# (17, 10)

# %%
merge_inner
# Out:
#         name                      email  age  entrydate gender  target  \
# 0       Glen            glent@gmail.com   23   19650409      M       0
# 1    Yinging        yirmic302@gmail.com   24   20070611      F       1
# 2     Lendor         kude1035@gmail.com   45   19900905      M       0
# 3    Tomocro    troman.telcon@gmail.com   27   19970819      M       1
# 4      Keren    tl.nesleeza@hotmail.com   58   19550902      M       0
# 5   Mafammia         mafuupink@yahoo.ca   28   19611127      F       1
# 6       Lina  Lina.centen1023@gmail.com   42   19970303      M       0
# 7      David        linta8892@gmail.com   63   19951012      M       0
# 8      David    denniel7008@hotmail.com   70   19900908      M       1
# 9       Mike          Mk03723@gmail.com   23   20050322      M       1
# 10      Mike          MMKK023@gmail.com   45   20051205      M       0
# 11     Zenik          Mufa.li@yahoo.com   27   19721201      M       1
# ...

# %%
merge_outer = pd.merge(people_fin, people_prof, on='email', how='outer')
merge_outer
# Out:
#                         email  amount  upperlevel    income education  \
# 0             glent@gmail.com   462.0       714.0   23113.3         U
# 1         yirmic302@gmail.com   215.0       571.0   20000.0         C
# 2          kude1035@gmail.com   185.0      1000.0   72000.0         C
# 3     troman.telcon@gmail.com    46.0       857.0   35000.0         C
# 4     tl.nesleeza@hotmail.com  1000.0       429.0   72000.0         U
# 5          mafuupink@yahoo.ca   338.0       714.0   90000.0         H
# 6   Lina.centen1023@gmail.com   185.0       429.0  160000.0         U
# 7       chimecll.lx@gmail.com    31.0         0.0   22000.0         U
# 8         linta8892@gmail.com   108.0       857.0   42999.0         H
# 9       yantming056@yahoo.com   200.0       429.0       0.0         U
# 10    denniel7008@hotmail.com   554.0       -90.0   21000.0         H
# 11          Mk03723@gmail.com   185.0       286.0   40000.0         H
# ...

# %%
people = people_fin.merge(people_prof, left_on='email', right_on='email', how='inner')
people.head()
# Out:
#                      email  amount  upperlevel   income education     name  \
# 0          glent@gmail.com     462         714  23113.3         U     Glen
# 1      yirmic302@gmail.com     215         571  20000.0         C  Yinging
# 2       kude1035@gmail.com     185        1000  72000.0         C   Lendor
# 3  troman.telcon@gmail.com      46         857  35000.0         C  Tomocro
# 4  tl.nesleeza@hotmail.com    1000         429  72000.0         U    Keren
#
#    age  entrydate gender  target
# 0   23   19650409      M       0
# 1   24   20070611      F       1
# 2   45   19900905      M       0
# 3   27   19970819      M       1
# 4   58   19550902      M       0

# %%
people = people_fin.merge(people_prof, left_on='email', right_on='email', how='outer')
D1 = people[people.age.isnull()]
D1
# Out:
#                     email  amount  upperlevel   income education name  age  \
# 7   chimecll.lx@gmail.com    31.0         0.0  22000.0         U  NaN  NaN
# 9   yantming056@yahoo.com   200.0       429.0      0.0         U  NaN  NaN
# 15      Tank0923@yahoo.ca     0.0         0.0      0.0         C  NaN  NaN
#
#     entrydate gender  target
# 7         NaN    NaN     NaN
# 9         NaN    NaN     NaN
# 15        NaN    NaN     NaN

# %%
people
# Out:
#                         email  amount  upperlevel    income education  \
# 0             glent@gmail.com   462.0       714.0   23113.3         U
# 1         yirmic302@gmail.com   215.0       571.0   20000.0         C
# 2          kude1035@gmail.com   185.0      1000.0   72000.0         C
# 3     troman.telcon@gmail.com    46.0       857.0   35000.0         C
# 4     tl.nesleeza@hotmail.com  1000.0       429.0   72000.0         U
# 5          mafuupink@yahoo.ca   338.0       714.0   90000.0         H
# 6   Lina.centen1023@gmail.com   185.0       429.0  160000.0         U
# 7       chimecll.lx@gmail.com    31.0         0.0   22000.0         U
# 8         linta8892@gmail.com   108.0       857.0   42999.0         H
# 9       yantming056@yahoo.com   200.0       429.0       0.0         U
# 10    denniel7008@hotmail.com   554.0       -90.0   21000.0         H
# 11          Mk03723@gmail.com   185.0       286.0   40000.0         H
# ...

# %%
people_fin.head()
# Out:
#                      email  amount  upperlevel   income education
# 0          glent@gmail.com     462         714  23113.3         U
# 1      yirmic302@gmail.com     215         571  20000.0         C
# 2       kude1035@gmail.com     185        1000  72000.0         C
# 3  troman.telcon@gmail.com      46         857  35000.0         C
# 4  tl.nesleeza@hotmail.com    1000         429  72000.0         U

# %%
people_prof.head()
# Out:
#       name                    email  age  entrydate gender  target
# 0     Glen          glent@gmail.com   23   19650409      M       0
# 1  Yinging      yirmic302@gmail.com   24   20070611      F       1
# 2   Lendor       kude1035@gmail.com   45   19900905      M       0
# 3  Tomocro  troman.telcon@gmail.com   27   19970819      M       1
# 4    Keren  tl.nesleeza@hotmail.com   58   19550902      M       0

# %%
people.head()
# Out:
#                      email  amount  upperlevel   income education     name  \
# 0          glent@gmail.com   462.0       714.0  23113.3         U     Glen
# 1      yirmic302@gmail.com   215.0       571.0  20000.0         C  Yinging
# 2       kude1035@gmail.com   185.0      1000.0  72000.0         C   Lendor
# 3  troman.telcon@gmail.com    46.0       857.0  35000.0         C  Tomocro
# 4  tl.nesleeza@hotmail.com  1000.0       429.0  72000.0         U    Keren
#
#     age   entrydate gender  target
# 0  23.0  19650409.0      M     0.0
# 1  24.0  20070611.0      F     1.0
# 2  45.0  19900905.0      M     0.0
# 3  27.0  19970819.0      M     1.0
# 4  58.0  19550902.0      M     0.0

# %%
people['both1'] = (people.age.notnull()) & (people.income.notnull())
people.head()
# Out:
#                      email  amount  upperlevel   income education     name  \
# 0          glent@gmail.com   462.0       714.0  23113.3         U     Glen
# 1      yirmic302@gmail.com   215.0       571.0  20000.0         C  Yinging
# 2       kude1035@gmail.com   185.0      1000.0  72000.0         C   Lendor
# 3  troman.telcon@gmail.com    46.0       857.0  35000.0         C  Tomocro
# 4  tl.nesleeza@hotmail.com  1000.0       429.0  72000.0         U    Keren
#
#     age   entrydate gender  target  both1
# 0  23.0  19650409.0      M     0.0   True
# 1  24.0  20070611.0      F     1.0   True
# 2  45.0  19900905.0      M     0.0   True
# 3  27.0  19970819.0      M     1.0   True
# 4  58.0  19550902.0      M     0.0   True

# %%
people['both2'] = (people.age.notnull()) | (people.income.notnull())
people.head()
# Out:
#                      email  amount  upperlevel   income education     name  \
# 0          glent@gmail.com   462.0       714.0  23113.3         U     Glen
# 1      yirmic302@gmail.com   215.0       571.0  20000.0         C  Yinging
# 2       kude1035@gmail.com   185.0      1000.0  72000.0         C   Lendor
# 3  troman.telcon@gmail.com    46.0       857.0  35000.0         C  Tomocro
# 4  tl.nesleeza@hotmail.com  1000.0       429.0  72000.0         U    Keren
#
#     age   entrydate gender  target  both1  both2
# 0  23.0  19650409.0      M     0.0   True   True
# 1  24.0  20070611.0      F     1.0   True   True
# 2  45.0  19900905.0      M     0.0   True   True
# 3  27.0  19970819.0      M     1.0   True   True
# 4  58.0  19550902.0      M     0.0   True   True

# %%
people
# Out:
#                         email  amount  upperlevel    income education  \
# 0             glent@gmail.com   462.0       714.0   23113.3         U
# 1         yirmic302@gmail.com   215.0       571.0   20000.0         C
# 2          kude1035@gmail.com   185.0      1000.0   72000.0         C
# 3     troman.telcon@gmail.com    46.0       857.0   35000.0         C
# 4     tl.nesleeza@hotmail.com  1000.0       429.0   72000.0         U
# 5          mafuupink@yahoo.ca   338.0       714.0   90000.0         H
# 6   Lina.centen1023@gmail.com   185.0       429.0  160000.0         U
# 7       chimecll.lx@gmail.com    31.0         0.0   22000.0         U
# 8         linta8892@gmail.com   108.0       857.0   42999.0         H
# 9       yantming056@yahoo.com   200.0       429.0       0.0         U
# 10    denniel7008@hotmail.com   554.0       -90.0   21000.0         H
# 11          Mk03723@gmail.com   185.0       286.0   40000.0         H
# ...

# %%
#same as &
people['both3'] = (people.age.notnull()) * (people.income.notnull())
people.head(8)
# Out:
#                        email  amount  upperlevel    income education  \
# 0            glent@gmail.com   462.0       714.0   23113.3         U
# 1        yirmic302@gmail.com   215.0       571.0   20000.0         C
# 2         kude1035@gmail.com   185.0      1000.0   72000.0         C
# 3    troman.telcon@gmail.com    46.0       857.0   35000.0         C
# 4    tl.nesleeza@hotmail.com  1000.0       429.0   72000.0         U
# 5         mafuupink@yahoo.ca   338.0       714.0   90000.0         H
# 6  Lina.centen1023@gmail.com   185.0       429.0  160000.0         U
# 7      chimecll.lx@gmail.com    31.0         0.0   22000.0         U
#
#        name   age   entrydate gender  target  both1  both2  both3
# 0      Glen  23.0  19650409.0      M     0.0   True   True   True
# 1   Yinging  24.0  20070611.0      F     1.0   True   True   True
# 2    Lendor  45.0  19900905.0      M     0.0   True   True   True
# 3   Tomocro  27.0  19970819.0      M     1.0   True   True   True
# ...

# %%
# same as |
people['both4'] = (people.age.notnull()) + (people.income.notnull())
people.head(8)
# Out:
#                        email  amount  upperlevel    income education  \
# 0            glent@gmail.com   462.0       714.0   23113.3         U
# 1        yirmic302@gmail.com   215.0       571.0   20000.0         C
# 2         kude1035@gmail.com   185.0      1000.0   72000.0         C
# 3    troman.telcon@gmail.com    46.0       857.0   35000.0         C
# 4    tl.nesleeza@hotmail.com  1000.0       429.0   72000.0         U
# 5         mafuupink@yahoo.ca   338.0       714.0   90000.0         H
# 6  Lina.centen1023@gmail.com   185.0       429.0  160000.0         U
# 7      chimecll.lx@gmail.com    31.0         0.0   22000.0         U
#
#        name   age   entrydate gender  target  both1  both2  both3  both4
# 0      Glen  23.0  19650409.0      M     0.0   True   True   True   True
# 1   Yinging  24.0  20070611.0      F     1.0   True   True   True   True
# 2    Lendor  45.0  19900905.0      M     0.0   True   True   True   True
# ...
